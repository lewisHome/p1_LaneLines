# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2
import os
import math
# %matplotlib inline

# %%
def grayscale(img):
    """Applies the Grayscale transform
    This will return an image with only one color channel
    but NOTE: to see the returned image as grayscale
    (assuming your grayscaled image is called 'gray')
    you should call plt.imshow(gray, cmap='gray')"""
    return cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    # Or use BGR2GRAY if you read an image with cv2.imread()
    # return cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
def canny(img, low_threshold, high_threshold):
    """Applies the Canny transform"""
    return cv2.Canny(img, low_threshold, high_threshold)

def gaussian_blur(img, kernel_size):
    """Applies a Gaussian Noise kernel"""
    return cv2.GaussianBlur(img, (kernel_size, kernel_size), 0)

def region_of_interest(img, vertices):
    """
    Applies an image mask.
    
    Only keeps the region of the image defined by the polygon
    formed from `vertices`. The rest of the image is set to black.
    """
    #defining a blank mask to start with
    mask = np.zeros_like(img)   
    
    #defining a 3 channel or 1 channel color to fill the mask with depending on the input image
    if len(img.shape) > 2:
        channel_count = img.shape[2]  # i.e. 3 or 4 depending on your image
        ignore_mask_color = (255,) * channel_count
    else:
        ignore_mask_color = 255
        
    #filling pixels inside the polygon defined by "vertices" with the fill color    
    cv2.fillPoly(mask, vertices, ignore_mask_color)
    
    #returning the image only where mask pixels are nonzero
    masked_image = cv2.bitwise_and(img, mask)
    return masked_image


def draw_lines(img, lines, color=[255, 0, 0], thickness=15):
    """
    NOTE: this is the function you might want to use as a starting point once you want to 
    average/extrapolate the line segments you detect to map out the full
    extent of the lane (going from the result shown in raw-lines-example.mp4
    to that shown in P1_example.mp4).  
    
    Think about things like separating line segments by their 
    slope ((y2-y1)/(x2-x1)) to decide which segments are part of the left
    line vs. the right line.  Then, you can average the position of each of 
    the lines and extrapolate to the top and bottom of the lane.
    
    This function draws `lines` with `color` and `thickness`.    
    Lines are drawn on the image inplace (mutates the image).
    If you want to make the lines semi-transparent, think about combining
    this function with the weighted_img() function below
    """
    global lineslast
    
    leftLineCount=0
    rightLineCount=0
    leftSum=np.zeros(4)
    rightSum=np.zeros(4)
    for line in lines:
        for x1,y1,x2,y2 in line:
            m=(y2-y1)/(x2-x1)
            if m < - 0.4 and m > -0.8:
                leftSum=np.add(leftSum,line)
                leftLineCount+=1
            elif m > 0.4 and m < 0.8:
                rightSum=np.add(rightSum,line)
                rightLineCount+=1
    try:
        leftAverage=np.zeros(4)            
        leftAverage[0]=(leftSum[0,0]/leftLineCount)
        leftAverage[1]=(leftSum[0,1]/leftLineCount)
        leftAverage[2]=(leftSum[0,2]/leftLineCount)
        leftAverage[3]=(leftSum[0,3]/leftLineCount)

        rightAverage=np.zeros(4)
        rightAverage[0]=(rightSum[0,0]/rightLineCount)
        rightAverage[1]=(rightSum[0,1]/rightLineCount)
        rightAverage[2]=(rightSum[0,2]/rightLineCount)
        rightAverage[3]=(rightSum[0,3]/rightLineCount)


        leftM=(leftAverage[3]-leftAverage[1])/(leftAverage[2]-leftAverage[0])
        leftB=leftAverage[1]-(leftM*leftAverage[0])
        leftLines=np.zeros((4),dtype=np.int)

        leftLines[1]=int(img.shape[0]/2+mskVert)
        leftLines[0]=int((leftLines[1]-leftB)/leftM)
        leftLines[3]=int(img.shape[0])
        leftLines[2]=int((leftLines[3]-leftB)/leftM)

        rightM=(rightAverage[3]-rightAverage[1])/(rightAverage[2]-rightAverage[0])
        rightB=rightAverage[1]-(rightM*rightAverage[0])
        rightLines=np.zeros((4),dtype=np.int)

        rightLines[1]=int(img.shape[0]/2+mskVert)
        rightLines[0]=int((rightLines[1]-rightB)/rightM)
        rightLines[3]=int(img.shape[0])
        rightLines[2]=int((rightLines[3]-rightB)/rightM)
        cv2.line(img, (leftLines[0], leftLines[1]), (leftLines[2], leftLines[3]), [255,0,0], thickness)
        cv2.line(img, (rightLines[0], rightLines[1]), (rightLines[2], rightLines[3]), [0,255,0], thickness)

        lineslast[0]=leftLines[0]
        lineslast[1]=leftLines[1]
        lineslast[2]=leftLines[2]
        lineslast[3]=leftLines[3]
        lineslast[4]=rightLines[0]
        lineslast[5]=rightLines[1]
        lineslast[6]=rightLines[2]
        lineslast[7]=rightLines[3]
    except:
        print("Warning! Error finding lines using old data")
        cv2.line(img, (lineslast[0], lineslast[1]), (lineslast[2], lineslast[3]), [255,0,0], thickness)
        cv2.line(img, (lineslast[4], lineslast[5]), (lineslast[6], lineslast[7]), [0,255,0], thickness)
def hough_lines(img, rho, theta, threshold, min_line_len, max_line_gap):
    """
    `img` should be the output of a Canny transform.
        
    Returns an image with hough lines drawn.
    """
    lines = cv2.HoughLinesP(img, rho, theta, threshold, np.array([]), minLineLength=min_line_len, maxLineGap=max_line_gap)
    line_img = np.zeros((img.shape[0], img.shape[1], 3), dtype=np.uint8)
    draw_lines(line_img,lines)
    return line_img

# Python 3 has support for cool math symbols.

def weighted_img(img, initial_img, α=0.5, β=1., λ=0.):
    """
    `img` is the output of the hough_lines(), An image with lines drawn on it.
    Should be a blank image (all black) with lines drawn on it.
    
    `initial_img` should be the image before any processing.
    
    The result image is computed as follows:
    
    initial_img * α + img * β + λ
    NOTE: initial_img and img must be the same shape!
    """
    return cv2.addWeighted(initial_img, α, img, β, λ)

# %%
kernel=5
blurAction= lambda image: gaussian_blur(image,kernel)

# %%
grayAction = lambda image: grayscale(image)

# %%
cannyLo = 50
cannyHi = 150
edgeAction = lambda image: canny(image, cannyLo, cannyHi)

# %%
mskVert=50
mskHorz=15
maskAction = lambda image: region_of_interest(image,np.array([[(0,image.shape[0]),((image.shape[1]/2)-mskHorz, (image.shape[0]/2)+mskVert), ((image.shape[1]/2)+mskHorz, (image.shape[0]/2)+mskVert), (image.shape[1],image.shape[0])]], dtype=np.int32)
)

# %%
rho = 1 # distance resolution in pixels of the Hough grid
theta = np.pi/180 # angular resolution in radians of the Hough grid
hoThresh = 75     # minimum number of votes (intersections in Hough grid cell)
hoMinLin = 3 #minimum number of pixels making up a line
hoMaxGap = 20    # maximum gap in pixels between connectable line segments
houghAction = lambda image: hough_lines(image,rho, theta, hoThresh, hoMinLin, hoMaxGap)

# %%
outputImageAction= lambda imageS: weighted_img(imageS[0],imageS[1])#, α=0.8, β=1., λ=0.5)

# %%
def procImage(image):
    return outputImageAction([image,houghAction(maskAction(edgeAction(blurAction(grayAction(image)))))])

# %%
for image in os.listdir("test_images/"):
    #reading in an image
    print (image)
    filePath="test_images/"+image
    lineView=procImage(cv2.imread(filePath))
    filePathOut='test_images/process_'+image
    plt.imshow(lineView, cmap="hsv")  # if you wanted to show a single color channel image called 'gray', for example, call as plt.imshow(gray, cmap='gray')
    plt.show()
# Out:
# solidWhiteRight.jpg
# [ 459.  320.  140.  540.  500.  320.  846.  540.]
# solidYellowLeft.jpg
# [ 460.  320.  146.  540.  496.  320.  849.  540.]
# whiteCarLaneSwitch.jpg
# [ 472.  320.  181.  540.  494.  320.  879.  540.]
# solidYellowCurve2.jpg
# [ 463.  320.  166.  540.  491.  320.  869.  540.]
# solidYellowCurve.jpg
# [ 466.  320.  163.  540.  494.  320.  861.  540.]
# solidWhiteCurve.jpg
# [ 467.  320.  170.  540.  500.  320.  892.  540.]

# %%
# Import everything needed to edit/save/watch video clips
from moviepy.editor import VideoFileClip
from IPython.display import HTML

# %%
def process_image(image):
    processedImage=houghAction(maskAction(cannyAction(blurAction(grayAction(image)))))
    return find_line(processedImage)

# %%
for video in os.listdir("test_videos/"):
    global lineslast
    lineslast=np.zeros((8),dtype=np.int)
    #reading video
    print (video)
    filePath="test_videos/"+video
    white_output = 'test_videos_output/'+str(video)
## To speed up the testing process you may want to try your pipeline on a shorter subclip of the video
## To do so add .subclip(start_second,end_second) to the end of the line below
## Where start_second and end_second are integer values representing the start and end of the subclip
## You may also uncomment the following line for a subclip of the first 5 seconds
##clip1 = VideoFileClip("test_videos/solidWhiteRight.mp4").subclip(0,5)
    clip = VideoFileClip(filePath)
    white_clip = clip.fl_image(procImage) #NOTE: this function expects color images!!
    white_clip.write_videofile(white_output, audio=False)
# Out:
# challenge.mp4
# [MoviePy] >>>> Building video test_videos_output/challenge.mp4
# [MoviePy] Writing video test_videos_output/challenge.mp4
#   0%|          | 0/251 [00:00<?, ?it/s]
#
#   1%|          | 2/251 [00:00<00:14, 17.27it/s]
# Warning! Error finding lines using old data
#   2%|▏         | 5/251 [00:00<00:12, 19.17it/s]
#
#   3%|▎         | 7/251 [00:00<00:12, 19.33it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#   4%|▍         | 10/251 [00:00<00:12, 19.66it/s]
#
#   5%|▍         | 12/251 [00:00<00:12, 18.64it/s]
#
#   6%|▌         | 15/251 [00:00<00:11, 21.02it/s]
#
#   8%|▊         | 19/251 [00:00<00:09, 23.41it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#   9%|▉         | 23/251 [00:00<00:09, 25.13it/s]
#
#  10%|█         | 26/251 [00:01<00:08, 25.00it/s]
#
#  12%|█▏        | 29/251 [00:01<00:08, 24.74it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  13%|█▎        | 32/251 [00:01<00:09, 23.64it/s]
#
#  14%|█▍        | 35/251 [00:01<00:10, 20.86it/s]
#
#  15%|█▌        | 38/251 [00:01<00:09, 21.55it/s]
#
#  16%|█▋        | 41/251 [00:01<00:08, 23.52it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  18%|█▊        | 45/251 [00:01<00:08, 24.45it/s]
#
#  19%|█▉        | 48/251 [00:02<00:19, 10.38it/s]
#
#  20%|█▉        | 50/251 [00:03<00:27,  7.28it/s]
#
#  21%|██        | 52/251 [00:03<00:23,  8.35it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#
/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  92%|█████████▏| 231/251 [00:20<00:01, 11.74it/s]
# Warning! Error finding lines using old data
#  93%|█████████▎| 233/251 [00:20<00:01, 10.68it/s]
#
#  94%|█████████▎| 235/251 [00:20<00:01, 10.89it/s]
#
#  94%|█████████▍| 237/251 [00:20<00:01, 10.62it/s]
#
#  95%|█████████▌| 239/251 [00:21<00:01, 11.04it/s]
#
#  96%|█████████▌| 241/251 [00:21<00:00, 10.97it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  97%|█████████▋| 243/251 [00:21<00:00, 11.38it/s]
#
#  98%|█████████▊| 245/251 [00:21<00:00, 10.92it/s]
#
#  98%|█████████▊| 247/251 [00:21<00:00, 10.93it/s]
#
#  99%|█████████▉| 249/251 [00:21<00:00, 11.83it/s]
#
# 100%|██████████| 251/251 [00:22<00:00, 12.08it/s]
# Warning! Error finding lines using old data
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: test_videos_output/challenge.mp4
#
# solidYellowLeft.mp4
# [MoviePy] >>>> Building video test_videos_output/solidYellowLeft.mp4
# [MoviePy] Writing video test_videos_output/solidYellowLeft.mp4
#   0%|          | 0/682 [00:00<?, ?it/s]
#
#   0%|          | 1/682 [00:00<03:12,  3.53it/s]
#
#   0%|          | 2/682 [00:00<02:44,  4.13it/s]
#
#   1%|          | 8/682 [00:00<01:57,  5.71it/s]
#
#   2%|▏         | 14/682 [00:00<01:25,  7.80it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#   3%|▎         | 18/682 [00:00<01:04, 10.26it/s]
#
#   3%|▎         | 23/682 [00:00<00:49, 13.23it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#   4%|▍         | 27/682 [00:01<00:41, 15.70it/s]
#
#   5%|▍         | 31/682 [00:01<00:35, 18.46it/s]
#
#   5%|▌         | 35/682 [00:01<00:30, 21.50it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#   6%|▌         | 39/682 [00:01<00:26, 24.04it/s]
#
#   6%|▋         | 43/682 [00:01<00:24, 25.58it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#   7%|▋         | 47/682 [00:01<00:26, 23.81it/s]
#
#   7%|▋         | 50/682 [00:01<00:26, 23.91it/s]
# Warning! Error finding lines using old data
#   8%|▊         | 53/682 [00:02<00:28, 21.96it/s]
#
#   8%|▊         | 56/682 [00:02<00:26, 23.59it/s]
#
#   9%|▊         | 59/682 [00:02<00:28, 22.24it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#   9%|▉         | 62/682 [00:02<00:27, 22.79it/s]
# Warning! Error finding lines using old data
#  10%|▉         | 65/682 [00:02<00:26, 22.95it/s]
#
#  10%|▉         | 68/682 [00:02<00:25, 23.75it/s]
#
#  10%|█         | 71/682 [00:02<00:28, 21.48it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  11%|█         | 74/682 [00:02<00:27, 21.91it/s]
#
#  11%|█▏        | 77/682 [00:03<00:27, 22.23it/s]
#
#  12%|█▏        | 80/682 [00:03<00:25, 23.40it/s]
#
#  12%|█▏        | 83/682 [00:03<00:25, 23.44it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  13%|█▎        | 86/682 [00:03<00:26, 22.47it/s]
#
#  13%|█▎        | 89/682 [00:03<00:25, 23.72it/s]
#
#  13%|█▎        | 92/682 [00:03<00:24, 23.99it/s]
#
#  14%|█▍        | 95/682 [00:03<00:26, 22.42it/s]
#
#  14%|█▍        | 98/682 [00:03<00:26, 22.45it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#
/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  73%|███████▎  | 497/682 [00:21<00:08, 21.90it/s]
#
#  73%|███████▎  | 500/682 [00:21<00:08, 21.87it/s]
#
#  74%|███████▍  | 503/682 [00:21<00:08, 21.66it/s]
#
#  74%|███████▍  | 506/682 [00:22<00:07, 22.98it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  75%|███████▍  | 509/682 [00:22<00:07, 21.79it/s]
#
#  75%|███████▌  | 512/682 [00:22<00:07, 22.43it/s]
#
#  76%|███████▌  | 515/682 [00:22<00:07, 21.17it/s]
#
#  76%|███████▌  | 518/682 [00:22<00:07, 21.81it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  76%|███████▋  | 521/682 [00:22<00:07, 20.23it/s]
#
#  77%|███████▋  | 524/682 [00:22<00:07, 21.11it/s]
#
#  77%|███████▋  | 527/682 [00:23<00:07, 21.14it/s]
#
#  78%|███████▊  | 530/682 [00:23<00:07, 20.54it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  78%|███████▊  | 533/682 [00:23<00:07, 20.99it/s]
#
#  79%|███████▊  | 536/682 [00:23<00:06, 22.51it/s]
#
#  79%|███████▉  | 539/682 [00:23<00:06, 21.86it/s]
#
#  79%|███████▉  | 542/682 [00:23<00:06, 22.63it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  80%|███████▉  | 545/682 [00:23<00:06, 20.70it/s]
#
#  80%|████████  | 548/682 [00:24<00:05, 22.70it/s]
#
#  81%|████████  | 551/682 [00:24<00:05, 23.71it/s]
#
#  81%|████████  | 554/682 [00:24<00:05, 23.01it/s]
#
#  82%|████████▏ | 557/682 [00:24<00:05, 23.34it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  82%|████████▏ | 560/682 [00:24<00:05, 22.84it/s]
#
#  83%|████████▎ | 563/682 [00:24<00:05, 21.54it/s]
#
#  83%|████████▎ | 566/682 [00:24<00:05, 21.98it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  83%|████████▎ | 569/682 [00:24<00:05, 20.91it/s]
#
#  84%|████████▍ | 572/682 [00:25<00:05, 21.62it/s]
#
#  84%|████████▍ | 575/682 [00:25<00:05, 20.89it/s]
#
#  85%|████████▍ | 578/682 [00:25<00:05, 20.80it/s]
#
#  85%|████████▌ | 581/682 [00:25<00:04, 21.95it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  86%|████████▌ | 584/682 [00:25<00:04, 20.90it/s]
#
#  86%|████████▌ | 587/682 [00:25<00:04, 20.42it/s]
#
#  87%|████████▋ | 590/682 [00:25<00:04, 20.48it/s]
#
#  87%|████████▋ | 593/682 [00:26<00:04, 21.75it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  87%|████████▋ | 596/682 [00:26<00:04, 20.47it/s]
#
#  88%|████████▊ | 599/682 [00:26<00:04, 20.64it/s]
#
#  88%|████████▊ | 602/682 [00:26<00:03, 20.82it/s]
#
#  89%|████████▊ | 605/682 [00:26<00:03, 22.48it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  89%|████████▉ | 608/682 [00:26<00:03, 21.50it/s]
#
#  90%|████████▉ | 611/682 [00:26<00:03, 21.29it/s]
#
#  90%|█████████ | 614/682 [00:27<00:03, 21.55it/s]
#
#  90%|█████████ | 617/682 [00:27<00:02, 22.79it/s]
# Warning! Error finding lines using old data
#  91%|█████████ | 620/682 [00:27<00:02, 22.08it/s]
#
#  91%|█████████▏| 623/682 [00:27<00:02, 22.45it/s]
#
#  92%|█████████▏| 626/682 [00:27<00:02, 21.26it/s]
#
#  92%|█████████▏| 629/682 [00:27<00:02, 22.17it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  93%|█████████▎| 632/682 [00:27<00:02, 21.55it/s]
#
#  93%|█████████▎| 635/682 [00:28<00:02, 21.34it/s]
#
#  94%|█████████▎| 638/682 [00:28<00:02, 21.03it/s]
#
#  94%|█████████▍| 641/682 [00:28<00:01, 22.32it/s]
#
#  94%|█████████▍| 644/682 [00:28<00:01, 22.19it/s]
# Warning! Error finding lines using old data
#  95%|█████████▍| 647/682 [00:28<00:01, 20.34it/s]
#
#  95%|█████████▌| 650/682 [00:28<00:01, 20.91it/s]
#
#  96%|█████████▌| 653/682 [00:28<00:01, 22.19it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  96%|█████████▌| 656/682 [00:29<00:01, 21.85it/s]
#
#  97%|█████████▋| 659/682 [00:29<00:01, 21.65it/s]
#
#  97%|█████████▋| 662/682 [00:29<00:00, 21.79it/s]
#
#  98%|█████████▊| 665/682 [00:29<00:00, 23.05it/s]
#
#  98%|█████████▊| 668/682 [00:29<00:00, 22.41it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  98%|█████████▊| 671/682 [00:29<00:00, 23.00it/s]
#
#  99%|█████████▉| 674/682 [00:29<00:00, 22.36it/s]
#
#  99%|█████████▉| 677/682 [00:29<00:00, 23.23it/s]
#
# 100%|█████████▉| 680/682 [00:30<00:00, 24.10it/s]
#
# 100%|█████████▉| 681/682 [00:30<00:00, 22.64it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: test_videos_output/solidYellowLeft.mp4
#
# solidWhiteRight.mp4
# [MoviePy] >>>> Building video test_videos_output/solidWhiteRight.mp4
# [MoviePy] Writing video test_videos_output/solidWhiteRight.mp4
#   0%|          | 0/222 [00:00<?, ?it/s]
#
#   1%|▏         | 3/222 [00:00<00:07, 27.48it/s]
#
#   4%|▍         | 9/222 [00:00<00:06, 32.72it/s]
#
#   7%|▋         | 15/222 [00:00<00:05, 37.72it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#   9%|▉         | 20/222 [00:00<00:05, 40.25it/s]
#
#  11%|█▏        | 25/222 [00:00<00:04, 42.40it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  14%|█▍        | 31/222 [00:00<00:04, 45.23it/s]
#
#  17%|█▋        | 38/222 [00:00<00:03, 48.58it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  19%|█▉        | 43/222 [00:00<00:03, 47.19it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  22%|██▏       | 48/222 [00:01<00:05, 34.26it/s]
#
#  23%|██▎       | 52/222 [00:01<00:06, 27.60it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  25%|██▌       | 56/222 [00:01<00:06, 23.81it/s]
#
#  27%|██▋       | 59/222 [00:01<00:06, 23.46it/s]
#
#  28%|██▊       | 62/222 [00:01<00:06, 24.70it/s]
#
#  29%|██▉       | 65/222 [00:01<00:06, 23.14it/s]
#
#  31%|███       | 68/222 [00:02<00:06, 22.68it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  32%|███▏      | 71/222 [00:02<00:06, 23.68it/s]
#
#  33%|███▎      | 74/222 [00:02<00:06, 24.38it/s]
# Warning! Error finding lines using old data
#  35%|███▍      | 77/222 [00:02<00:05, 24.44it/s]
#
#  36%|███▌      | 80/222 [00:02<00:05, 24.74it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  37%|███▋      | 83/222 [00:02<00:05, 25.01it/s]
#
#  39%|███▊      | 86/222 [00:02<00:05, 24.90it/s]
#
#  40%|████      | 89/222 [00:02<00:05, 24.41it/s]
#
#  41%|████▏     | 92/222 [00:03<00:05, 24.95it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  43%|████▎     | 95/222 [00:03<00:05, 24.57it/s]
#
#  45%|████▍     | 99/222 [00:03<00:04, 26.64it/s]
#
#  46%|████▌     | 102/222 [00:03<00:04, 25.56it/s]
#
#  47%|████▋     | 105/222 [00:03<00:04, 24.30it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  49%|████▊     | 108/222 [00:03<00:04, 24.71it/s]
#
#  50%|█████     | 111/222 [00:03<00:04, 25.32it/s]
#
#  51%|█████▏    | 114/222 [00:03<00:04, 24.76it/s]
#
#  53%|█████▎    | 117/222 [00:03<00:04, 25.09it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  54%|█████▍    | 120/222 [00:04<00:04, 24.67it/s]
#
#  55%|█████▌    | 123/222 [00:04<00:03, 25.14it/s]
#
#  57%|█████▋    | 126/222 [00:04<00:03, 25.37it/s]
#
#  58%|█████▊    | 129/222 [00:04<00:03, 25.04it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  59%|█████▉    | 132/222 [00:04<00:03, 24.99it/s]
#
#  61%|██████    | 135/222 [00:04<00:03, 23.89it/s]
#
#  62%|██████▏   | 138/222 [00:04<00:03, 21.42it/s]
#
#  64%|██████▎   | 141/222 [00:05<00:03, 22.17it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  65%|██████▍   | 144/222 [00:05<00:03, 22.98it/s]
#
#  67%|██████▋   | 148/222 [00:05<00:03, 23.39it/s]
#
#  68%|██████▊   | 152/222 [00:05<00:02, 24.18it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  70%|███████   | 156/222 [00:05<00:02, 23.14it/s]
#
#  72%|███████▏  | 159/222 [00:05<00:02, 23.79it/s]
#
#  73%|███████▎  | 162/222 [00:05<00:02, 20.46it/s]
#
#  74%|███████▍  | 165/222 [00:06<00:02, 21.16it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  76%|███████▌  | 168/222 [00:06<00:02, 20.43it/s]
#
#  77%|███████▋  | 172/222 [00:06<00:02, 22.14it/s]
#
#  79%|███████▉  | 176/222 [00:06<00:01, 23.08it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  81%|████████  | 180/222 [00:06<00:01, 23.15it/s]
#
#  82%|████████▏ | 183/222 [00:06<00:01, 24.78it/s]
#
#  84%|████████▍ | 186/222 [00:06<00:01, 23.77it/s]
#
#  85%|████████▌ | 189/222 [00:07<00:01, 23.38it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  86%|████████▋ | 192/222 [00:07<00:01, 23.97it/s]
#
#  88%|████████▊ | 195/222 [00:07<00:01, 24.61it/s]
#
#  89%|████████▉ | 198/222 [00:07<00:01, 23.44it/s]
#
#  91%|█████████ | 201/222 [00:07<00:00, 23.70it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  92%|█████████▏| 204/222 [00:07<00:00, 23.59it/s]
#
#  93%|█████████▎| 207/222 [00:07<00:00, 24.96it/s]
#
#  95%|█████████▍| 210/222 [00:07<00:00, 23.96it/s]
#
#  96%|█████████▌| 213/222 [00:08<00:00, 23.64it/s]
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
# Warning! Error finding lines using old data
#  97%|█████████▋| 216/222 [00:08<00:00, 23.46it/s]
#
#  99%|█████████▊| 219/222 [00:08<00:00, 23.99it/s]
#
# 100%|█████████▉| 221/222 [00:08<00:00, 26.21it/s]
# Warning! Error finding lines using old data
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: test_videos_output/solidWhiteRight.mp4
